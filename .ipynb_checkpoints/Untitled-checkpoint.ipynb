# %%
import pandas as pd

# %%
#importing and reading csv files as dataframe

file1=pd.read_csv('file1.csv')
file2=pd.read_csv('file2.csv')
file3=pd.read_csv('file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# checking shape of the dataframes
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
# Standardize header names.
file1=file1.rename({'ST': 'State','GENDER':'Gender'}, axis=1)
file1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
columns_name1=file1.columns

# %%
columns_name1
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2=file2.rename({'ST': 'State', 'GENDER':'Gender'}, axis=1)
file2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
columns_name2=file2.columns
columns_name2
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
columns_name3=file3.columns
columns_name3
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
columns_name1
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#Rearrange the columns in the dataframe as needed
file1_ordered=file1.loc[:, ['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender','Income', 'Monthly Premium Auto', 'Number of Open Complaints','Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
file1_ordered
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 4003      NaN         NaN                     NaN                   NaN
# 4004      NaN         NaN                     NaN                   NaN
# 4005      NaN         NaN                     NaN                   NaN
# 4006      NaN         NaN                     NaN                   NaN
# 4007      NaN         NaN                     NaN                   NaN
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
columns_name1
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
column_name=file1_ordered.columns

# %%
column_name
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df=pd.DataFrame(columns=column_name)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
# Concatenate the three dataframes
df=pd.concat([df,file1_ordered],axis=0)

# %%
df
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 4003      NaN         NaN                     NaN                   NaN
# 4004      NaN         NaN                     NaN                   NaN
# 4005      NaN         NaN                     NaN                   NaN
# 4006      NaN         NaN                     NaN                   NaN
# 4007      NaN         NaN                     NaN                   NaN
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
df_tot=pd.concat([df,file2,file3],axis=0)

# %%
df_tot
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California                   23406              Bachelor
# 7066  PK87824  California                 3096.51               College
# 7067  TD14365  California                 8163.89              Bachelor
# 7068  UP19263  California                 7524.44               College
# 7069  Y167826  California                 2611.84               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
df_tot.shape
# Out:
# (12074, 11)

# %%
df_tot.info
# Out:
# <bound method DataFrame.info of      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California                   23406              Bachelor
# 7066  PK87824  California                 3096.51               College
# 7067  TD14365  California                 8163.89              Bachelor
# 7068  UP19263  California                 7524.44               College
# 7069  Y167826  California                 2611.84               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
df_tot.reset_index
# Out:
# <bound method DataFrame.reset_index of      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California                   23406              Bachelor
# 7066  PK87824  California                 3096.51               College
# 7067  TD14365  California                 8163.89              Bachelor
# 7068  UP19263  California                 7524.44               College
# 7069  Y167826  California                 2611.84               College
#
# ...

# %%
df_tot
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California                   23406              Bachelor
# 7066  PK87824  California                 3096.51               College
# 7067  TD14365  California                 8163.89              Bachelor
# 7068  UP19263  California                 7524.44               College
# 7069  Y167826  California                 2611.84               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
# categorical data
categorical_columns = df_tot.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class']

# %%
# numerical data
numerical_columns = df_tot.select_dtypes(exclude=['object']).columns.tolist()
numerical_columns
# Out:
# ['Income', 'Monthly Premium Auto', 'Total Claim Amount']

# %%
# Performing the data cleaning operations mentioned so far in class
# deleting 'Education' and 'Number of Open Complaints' columns
df_mod=df_tot.drop(['Education','Number of Open Complaints'], axis = 1)

# %%
df_mod
# Out:
#      Customer       State Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                     NaN    NaN      0.0
# 1     QZ44356     Arizona              697953.59%      F      0.0
# 2     AI49188      Nevada             1288743.17%      F  48767.0
# 3     WW63253  California              764586.18%      M      0.0
# 4     GA49547  Washington              536307.65%      M  36357.0
# ...       ...         ...                     ...    ...      ...
# 7065  LA72316  California                   23406      M  71941.0
# 7066  PK87824  California                 3096.51      F  21604.0
# 7067  TD14365  California                 8163.89      M      0.0
# 7068  UP19263  California                 7524.44      M  21941.0
# 7069  Y167826  California                 2611.84      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
df2=df_mod.copy()

# %%
df_modified=df2["Customer Lifetime Value"] = df2["Customer Lifetime Value"].map(lambda x: str(x).rstrip('%'))
df_modified= df_modified.map(lambda x: float(x)*100)
df_modified
#df2["Customer Lifetime Value"] = pd.to_numeric(df2["Customer Lifetime Value"])
# Out:
# 0                NaN
# 1       6.979536e+07
# 2       1.288743e+08
# 3       7.645862e+07
# 4       5.363076e+07
#             ...
# 7065    2.340599e+06
# 7066    3.096511e+05
# 7067    8.163890e+05
# 7068    7.524442e+05
# 7069    2.611837e+05
# Name: Customer Lifetime Value, Length: 12074, dtype: float64

# %%
df2["Customer Lifetime Value"]=df_modified

# %%
df2
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona             6.979536e+07      F      0.0
# 2     AI49188      Nevada             1.288743e+08      F  48767.0
# 3     WW63253  California             7.645862e+07      M      0.0
# 4     GA49547  Washington             5.363076e+07      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             2.340599e+06      M  71941.0
# 7066  PK87824  California             3.096511e+05      F  21604.0
# 7067  TD14365  California             8.163890e+05      M      0.0
# 7068  UP19263  California             7.524442e+05      M  21941.0
# 7069  Y167826  California             2.611837e+05      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
# Undersatnding the data
df2.describe(include = 'all')
# Out:
#        Customer       State  Customer Lifetime Value Gender        Income  \
# count      9137        9137             9.130000e+03   9015   9137.000000
# unique     9056           8                      NaN      5           NaN
# top     TL18087  California                      NaN      F           NaN
# freq          2        3032                      NaN   4560           NaN
# mean        NaN         NaN             1.821964e+07    NaN  37828.820291
# std         NaN         NaN             4.410502e+07    NaN  30358.716159
# min         NaN         NaN             1.898008e+05    NaN      0.000000
# 25%         NaN         NaN             4.650064e+05    NaN      0.000000
# 50%         NaN         NaN             7.714877e+05    NaN  34244.000000
# 75%         NaN         NaN             2.619741e+06    NaN  62447.000000
# max         NaN         NaN             5.816655e+08    NaN  99981.000000
#
#         Monthly Premium Auto    Policy Type  Total Claim Amount  Vehicle Class
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer                 9137 non-null   object
#  1   State                    9137 non-null   object
#  2   Customer Lifetime Value  9130 non-null   float64
#  3   Gender                   9015 non-null   object
#  4   Income                   9137 non-null   float64
#  5   Monthly Premium Auto     9137 non-null   float64
#  6   Policy Type              9137 non-null   object
#  7   Total Claim Amount       9137 non-null   float64
#  8   Vehicle Class            9137 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 943.3+ KB

# %%
# Check for duplicate rows in the data and remove if any.
df2.loc[df2.duplicated(), :]
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 1072      NaN         NaN                      NaN    NaN      NaN
# 1073      NaN         NaN                      NaN    NaN      NaN
# 1074      NaN         NaN                      NaN    NaN      NaN
# 1075      NaN         NaN                      NaN    NaN      NaN
# 1076      NaN         NaN                      NaN    NaN      NaN
# ...       ...         ...                      ...    ...      ...
# 4006      NaN         NaN                      NaN    NaN      NaN
# 4007      NaN         NaN                      NaN    NaN      NaN
# 0     GS98873     Arizona               32391247.0      F  16061.0
# 1     CW49887  California               46268011.0      F  79487.0
# 2     MY31220  California               89970402.0      F  54230.0
#
#       Monthly Premium Auto    Policy Type  Total Claim Amount  Vehicle Class
# 1072                   NaN            NaN                 NaN            NaN
# ...

# %%
df3=df2.drop_duplicates()
df3
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona             6.979536e+07      F      0.0
# 2     AI49188      Nevada             1.288743e+08      F  48767.0
# 3     WW63253  California             7.645862e+07      M      0.0
# 4     GA49547  Washington             5.363076e+07      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             2.340599e+06      M  71941.0
# 7066  PK87824  California             3.096511e+05      F  21604.0
# 7067  TD14365  California             8.163890e+05      M      0.0
# 7068  UP19263  California             7.524442e+05      M  21941.0
# 7069  Y167826  California             2.611837e+05      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
df2.duplicated().sum()
# Out:
# 2939

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
# Filter out the data for customers who have an income of 0 or less.
df_lowIncome= df3[df3['Income']<=0]
df_lowIncome
# Out:
#      Customer       State  Customer Lifetime Value Gender  Income  \
# 0     RB50392  Washington                      NaN    NaN     0.0
# 1     QZ44356     Arizona             6.979536e+07      F     0.0
# 3     WW63253  California             7.645862e+07      M     0.0
# 7     CF85061     Arizona             7.216100e+07      M     0.0
# 10    SX51350  California             4.738992e+07      M     0.0
# ...       ...         ...                      ...    ...     ...
# 7059  WZ45103  California             5.678050e+05      F     0.0
# 7061  RX91025  California             1.987226e+06      M     0.0
# 7062  AC13887  California             4.628995e+05      M     0.0
# 7067  TD14365  California             8.163890e+05      M     0.0
# 7069  Y167826  California             2.611837e+05      M     0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
# checking the percentage of the missing data
df3.isna().sum()
# Out:
# Customer                     1
# State                        1
# Customer Lifetime Value      8
# Gender                     123
# Income                       1
# Monthly Premium Auto         1
# Policy Type                  1
# Total Claim Amount           1
# Vehicle Class                1
# dtype: int64

# %%
nulls_df = pd.DataFrame(round(df3.isna().sum()/len(df3)*100,2))
nulls_df
# Out:
#                             0
# Customer                 0.01
# State                    0.01
# Customer Lifetime Value  0.09
# Gender                   1.35
# Income                   0.01
# Monthly Premium Auto     0.01
# Policy Type              0.01
# Total Claim Amount       0.01
# Vehicle Class            0.01

# %%
 nulls_df = nulls_df.reset_index()
 nulls_df.columns = ['header_name', '%_null_values']

# %%
nulls_df
# Out:
#                header_name  %_null_values
# 0                 Customer           0.01
# 1                    State           0.01
# 2  Customer Lifetime Value           0.09
# 3                   Gender           1.35
# 4                   Income           0.01
# 5     Monthly Premium Auto           0.01
# 6              Policy Type           0.01
# 7       Total Claim Amount           0.01
# 8            Vehicle Class           0.01
